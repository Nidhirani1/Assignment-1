# %%
# # Q1. Explain Class and Object with respect to Object-Oriented Programming. Give a suitable example.
# Ans:-
# Class and Object in Object-Oriented Programming
# In Object-Oriented Programming (OOP), the concepts of class and object are fundamental building blocks.

# Class:
# A class is a blueprint or template for creating objects. 
# It defines a set of attributes and methods that the created objects (instances) will have. 
# Classes encapsulate data for the object and methods to manipulate that data. 
# They are used to create objects with specific properties and behaviors.

# Object:
# An object is an instance of a class. When a class is defined, 
# no memory is allocated until an object of that class is created. 
# Each object has its own set of attributes and can use the methods defined in the class. 
# Objects represent real-world entities or concepts.

# Example:
# Let's consider a real-world example of a "Car".

# Class Definition:

# class Car:
#     def __init__(self, make, model, year):
#         self.make = make
#         self.model = model
#         self.year = year
#         self.speed = 0
    
#     def accelerate(self, increase):
#         self.speed += increase
#         print(f"The car has accelerated to {self.speed} mph.")
    
#     def brake(self, decrease):
#         self.speed -= decrease
#         if self.speed < 0:
#             self.speed = 0
#         print(f"The car has slowed down to {self.speed} mph.")
    
#     def honk(self):
#         print("Honk! Honk!")
# Here, Car is a class with attributes make, model, year, and speed. 
# It has methods accelerate, brake, and honk.

# Creating Objects:


# car1 = Car("Toyota", "Corolla", 2020)
# car2 = Car("Honda", "Civic", 2018)
# Here, car1 and car2 are objects of the Car class. 
# Each object has its own set of attributes and can use the methods defined in the class.

# Using Objects:



# car1.accelerate(30)
# car1.brake(10)
# car1.honk()

# car2.accelerate(50)
# car2.brake(20)
# car2.honk()
# The methods accelerate, brake, and honk are called on the objects car1 and car2. 
# Each object maintains its own state.

# %%
# # Q2. Name the four pillars of OOPs.
# Ans:-
# 1>Encapsulation:

# Encapsulation is the concept of wrapping data (variables) and methods (functions) together into a single unit,
# known as a class. It restricts direct access to some of the object's components, 
# which can protect the integrity of the data and hide the internal implementation details from the outside world. 
# This is typically achieved using access modifiers like private, protected, and public.

# 2>Abstraction:

# Abstraction is the process of hiding the complex implementation details and 
# showing only the necessary features of an object. It allows users to interact with the object 
# through a simplified interface. Abstraction helps in reducing programming complexity and effort.
# It focuses on what an object does instead of how it does it.


# 3>Inheritance:

# Inheritance is the mechanism by which one class (called the child or subclass) can inherit properties and 
# behaviors (methods) from another class (called the parent or superclass). It promotes code reusability and 
# establishes a natural hierarchy between classes. For example, a Dog class can inherit from an Animal class, 
# meaning Dog would automatically have the properties and methods defined in Animal.

# 4>Polymorphism:

# Polymorphism means "many shapes" and it allows objects to be treated as instances of their parent class
# rather than their actual class. The most common use of polymorphism is when a parent class reference is
# used to refer to a child class object. Polymorphism can be achieved through method overriding
# (runtime polymorphism) and method overloading (compile-time polymorphism).

# %%
# # Q3. Explain why the __init__() function is used. Give a suitable example.
# Ans:-The __init__() Function in Python
# The __init__() function is a special method in Python, commonly referred to as the constructor. 
# It is automatically called when a new instance of a class is created. The primary purpose of __init__() is
# to initialize the object's attributes with user-defined values or default values. 
# This method allows you to set up the initial state of an object upon creation.

# Key Points:
# __init__() is used to initialize an object's state.
# It is the first method that runs when an instance of a class is instantiated.
# It can take additional arguments besides self to set attributes with user-defined values.
# Example:
# Let's illustrate the use of __init__() with an example of a Person class.


# class Person:
#     def __init__(self, name, age, city):
#         self.name = name
#         self.age = age
#         self.city = city
    
#     def display_info(self):
#         print(f"Name: {self.name}, Age: {self.age}, City: {self.city}")

# # Creating instances of the Person class
# person1 = Person("Alice", 30, "New York")
# person2 = Person("Bob", 25, "Los Angeles")

# # Displaying information about each person
# person1.display_info()  # Output: Name: Alice, Age: 30, City: New York
# person2.display_info()  # Output: Name: Bob, Age: 25, City: Los Angeles
# Explanation:
# Class Definition:


# class Person:
#     def __init__(self, name, age, city):
#         self.name = name
#         self.age = age
#         self.city = city
# The Person class has an __init__() method that takes three parameters: name, age, and city.
# Inside __init__(), the attributes self.name, self.age, and self.city are initialized with the 
# values passed to the constructor when a Person object is created.

# Creating Instances:


# person1 = Person("Alice", 30, "New York")
# person2 = Person("Bob", 25, "Los Angeles")
# Two instances of the Person class are created: person1 and person2.
# The __init__() method is called for each instance, initializing the attributes with the provided values.
# Using Methods:


# def display_info(self):
#     print(f"Name: {self.name}, Age: {self.age}, City: {self.city}")
# The display_info() method is defined to display the information of the Person object.
# Calling person1.display_info() and person2.display_info() prints the initialized values of the respective objects.

# %%
# # Q4. Why self is used in OOPs?
# Ans>The Role of self in Object-Oriented Programming
# In Object-Oriented Programming (OOP) in Python, self is a reference to the instance of the class.
# It is used to access variables and methods associated with the instance. 
# The self parameter is a convention in Python and is used explicitly to differentiate between instance 
# variables and local variables.

# Key Points:
# Instance Reference: self refers to the current instance of the class.
# Accessing Attributes and Methods: self is used to access attributes and methods within the class.
# Mandatory in Instance Methods: self is the first parameter of any instance method in a class.
# Although you can name it differently, using self is a widely accepted convention.
# Why self is Important:
# Accessing Instance Variables:

# When an instance variable is declared, it is prefixed with self to indicate that it belongs to the instance.
# Accessing Methods:

# To call other methods from within the class, you use self.method_name().
# Differentiation:

# It distinguishes between instance variables (associated with self) and 
# local variables (defined within a method without self).
# Example:
# Let's look at an example of a Car class to see how self is used:

# python
# Copy code
# class Car:
#     def __init__(self, make, model, year):
#         self.make = make
#         self.model = model
#         self.year = year
#         self.speed = 0

#     def accelerate(self, increase):
#         self.speed += increase
#         print(f"The car has accelerated to {self.speed} mph.")
    
#     def brake(self, decrease):
#         self.speed -= decrease
#         if self.speed < 0:
#             self.speed = 0
#         print(f"The car has slowed down to {self.speed} mph.")
    
#     def display_info(self):
#         print(f"Make: {self.make}, Model: {self.model}, Year: {self.year}, Speed: {self.speed} mph")

# # Creating an instance of the Car class
# my_car = Car("Toyota", "Corolla", 2020)

# # Using methods of the Car class
# my_car.accelerate(30)
# my_car.brake(10)
# my_car.display_info()
# Explanation:
# Initializing the Object:


# def __init__(self, make, model, year):
#     self.make = make
#     self.model = model
#     self.year = year
#     self.speed = 0
# The __init__ method initializes the object's attributes.
# The self.make, self.model, self.year, and self.speed are instance variables.
# Using self in Methods:


# def accelerate(self, increase):
#     self.speed += increase
#     print(f"The car has accelerated to {self.speed} mph.")
# The accelerate method modifies the instance variable self.speed. 
# The use of self ensures that speed is recognized as an instance variable.
# Calling Methods:


# def display_info(self):
#     print(f"Make: {self.make}, Model: {self.model}, Year: {self.year}, Speed: {self.speed} mph")
# The display_info method uses self to access and print the instance variables of the class.

# %%
Q5. What is inheritance? Give an example for each type of inheritance.
Ans>
