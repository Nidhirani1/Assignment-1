# %%
# Q1. What is multithreading in python? Why is it used? Name the module used to handle threads in python.
# Ans:-
# Multithreading in Python refers to the concurrent execution of two or more threads within a single process. A thread is the smallest unit of execution within a process, and multithreading allows a program to perform multiple operations simultaneously.

# Why Multithreading is Used:

# Concurrency: Multithreading helps in running multiple tasks at the same time, which can improve the efficiency of certain applications, particularly those involving I/O operations or tasks that are inherently concurrent.
# Responsiveness: In user-interface applications, multithreading can help keep the application responsive by performing background tasks without freezing the main application thread.
# Resource Sharing: Threads within the same process share memory and resources, making it easier to share data between tasks without needing complex inter-process communication mechanisms.
# Module for Handling Threads:

# In Python, the threading module is used to handle threads. It provides a way to create and manage threads, synchronize their execution, and handle thread-related tasks. Here's a simple example of how to use it:


# import threading

# def worker():
#     print("Thread is running")

# # Create a new thread
# thread = threading.Thread(target=worker)

# # Start the thread
# thread.start()

# # Wait for the thread to complete
# thread.join()

# %%
# Q2. Why threading module used? Write the use of the following functions
# ( activeCount(
#  currentThread(
#  enumerate()
# Ans:-The threading module in Python provides a way to work with threads, allowing you to create and manage threads in your programs. It is particularly useful for tasks that can benefit from concurrent execution, such as I/O-bound tasks, background processing, or applications that need to remain responsive.

# Use of Functions in threading Module:
# threading.activeCount()

# Purpose: Returns the number of Thread objects currently alive. This function provides a quick way to see how many threads are currently running in the application.

# Usage Example:


# import threading

# def worker():
#     print("Thread is running")

# # Create and start threads
# threads = [threading.Thread(target=worker) for _ in range(5)]
# for thread in threads:
#     thread.start()

# # Get the number of active threads
# print(f"Active threads: {threading.activeCount()}")
# Output: The output will show the number of active threads, which includes the main thread and any additional threads that were started.

# threading.currentThread()

# Purpose: Returns the Thread object corresponding to the caller’s thread of control. This function is useful for identifying or working with the current thread.

# Usage Example:


# import threading

# def worker():
#     print(f"Current thread: {threading.currentThread().name}")

# # Create and start a thread
# thread = threading.Thread(target=worker, name="WorkerThread")
# thread.start()
# thread.join()
# Output: The output will display the name of the current thread, which in this case is "WorkerThread".

# threading.enumerate()

# Purpose: Returns a list of all Thread objects currently alive. 
# This includes the main thread and any other threads that have been started and are still running. This function is useful for inspecting all threads in the application.

# Usage Example:


# import threading

# def worker():
#     print("Thread is running")

# # Create and start threads
# threads = [threading.Thread(target=worker) for _ in range(3)]
# for thread in threads:
#     thread.start()

# # Get a list of all alive threads
# alive_threads = threading.enumerate()
# print(f"Alive threads: {[thread.name for thread in alive_threads]}")
# Output: The output will show a list of names of all threads that are currently alive,
#      including the main thread and any additional threads started by the application.

# %%
# Q3. Explain the following functions
# ( run(
#  start(
#  join(
# ' isAlive()
# Ans:-In Python's threading module, the following functions are integral to thread management and control. Here's an explanation of each:

# 1. run()
# Purpose: The run() method is defined in the Thread class and is intended to contain the code that will be executed by the thread. By default, this method calls the target function provided when creating the thread. If you subclass Thread, you can override this method to define the behavior of your thread.

# Usage Example:

# python
# Copy code
# import threading

# class MyThread(threading.Thread):
#     def run(self):
#         print("Thread is running")

# # Create and start the thread
# thread = MyThread()
# thread.start()
# Explanation: In this example, MyThread overrides the run() method to specify what should happen when the thread is started. When thread.start() is called, it internally calls the run() method.

# 2. start()
# Purpose: The start() method begins the thread’s activity. When you call start(), the thread is initialized and the run() method is invoked in a new thread of control.

# Usage Example:

# python
# Copy code
# import threading

# def worker():
#     print("Thread is running")

# # Create a thread
# thread = threading.Thread(target=worker)

# # Start the thread
# thread.start()
# Explanation: Here, thread.start() initiates the thread and causes it to run the worker function. This method must be called to begin the thread’s execution.

# 3. join()
# Purpose: The join() method is used to wait for a thread to complete its execution. When you call join() on a thread, the calling thread (often the main thread) is blocked until the thread on which join() was called finishes.

# Usage Example:


# import threading

# def worker():
#     print("Thread is running")

# # Create and start the thread
# thread = threading.Thread(target=worker)
# thread.start()

# # Wait for the thread to finish
# thread.join()
# print("Thread has finished")
# Explanation: In this example, thread.join() blocks the main thread until the worker thread completes. This ensures that "Thread has finished" is printed only after the worker thread has completed its execution.

# 4. is_alive()
# Purpose: The is_alive() method checks whether the thread is still alive (i.e., whether it has finished execution or not). It returns True if the thread is still running and False if it has finished or has not been started.

# Usage Example:


# import threading
# import time

# def worker():
#     time.sleep(2)
#     print("Thread has finished")

# # Create and start the thread
# thread = threading.Thread(target=worker)
# thread.start()

# # Check if the thread is alive
# print(f"Is thread alive? {thread.is_alive()}")

# # Wait for the thread to complete
# thread.join()

# # Check again if the thread is alive
# print(f"Is thread alive? {thread.is_alive()}")
# Explanation: Before calling join(), thread.is_alive() returns True because the thread is still running. After join() has been called and the thread completes, thread.is_alive() returns False

# %%
#

# %%
Q5. State advantages and disadvantages of multithreading.
Ans:-
