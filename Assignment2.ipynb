# %%
# Q1. How do you comment code in Python? What are the different types of comments?
# ans-IN puthon u can coment with the help of (#).Comments are used to explain the code for better understanding, 
#     and they are not executed as part of the program.
#     There r two types of comment code:
#     1>single line comment 
#     2>Multiple line comment
    
#     1>single line comment:
#     These comments start with the # symbol and extend to the end of the line. 
#     They are used for short, inline explanations.
    
#     example:
#     # This is a single-line comment
    
#     2>Multiple line comment:These comments span multiple lines and are enclosed within triple quotes (''' or """). 
#     While they are not technically comments,
#     they are often used as such for documenting functions, classes, or modules.
    
#     example:
#     '''
#       This is a multi-line comment (docstring).
#       It can span multiple lines and is often used for documentation.
#     # '''

# %%
# Q2. What are variables in Python? How do you declare and assign values to variables?
# Ans:-In Python, variables are used to store data values. 
# These values can be of various types, such as numbers, strings, lists, dictionaries, etc. 
# Variables act as labels or references to memory locations where data is stored.



# now ,In Python, variables are used to store data values. 
# These values can be of various types, such as numbers, strings, lists, dictionaries, etc. 
# Variables act as labels or references to memory locations where data is stored.



# Example:

# Assigning a value to a variable
# my_variable = 10

# # You can also assign values of different types to the same variable
# my_variable = "Hello, Python!"

# # You can assign the result of an expression to a variable
# result = 10 + 5

# # Variables can store different types of data
# name = "Alice"
# age = 30
# is_student = True






# Python variable names must follow these rules:

# 1>Variable names can only contain letters (a-z, A-Z), digits (0-9), and underscores (_).
# 2>Variable names cannot start with a digit.
# 3>Variable names are case-sensitive (my_variable, My_Variable, and MY_VARIABLE are three different variables).
# 4>Variable names cannot be Python keywords or reserved words (like if, for, while, True, False, None, etc.).
# You can reassign a new value to an existing variable at any time, 



# and the variable will then reference the new value. Python also supports multiple assignment, 
# allowing you to assign multiple variables in a single line.

# Example:
# x = 5
# x = "Hello"  # Reassigning x to a string value

# # Multiple assignment
# a, b, c = 1, 2, 3

# %%
# Q3. How do you convert one data type to another in Python?
# Ans:-In Python, you can convert one data type to another using built-in functions or methods. 
# Here are some common conversion methods:

# 1>Implicit Conversion (Automatic Type Conversion): Python automatically converts data types in certain situations, 
# such as when performing arithmetic operations between different types. For example, 
# if you add an integer to a float, Python will automatically convert the integer to a float before performing 
# the addition.


# Example:
# x = 5  # integer
# y = 2.5  # float

# result = x + y  # Python converts x to float before adding
# print(result)  # Output: 7.5

# 2>Explicit Conversion (Type Casting): You can explicitly convert one data type to another using built-in functions
# like int(),float(), str(), list(), tuple(), set(), dict(), etc.

# Example:
# # Converting to integer
# x = int(5.7)  # x will be 5
# y = int("10")  # y will be 10

# # Converting to float
# a = float(5)  # a will be 5.0
# b = float("3.14")  # b will be 3.14

# # Converting to string
# s = str(10)  # s will be "10"
# t = str(3.14)  # t will be "3.14"

# # Converting to list
# lst = list((1, 2, 3))  # lst will be [1, 2, 3]

# # Converting to tuple
# tpl = tuple([1, 2, 3])  # tpl will be (1, 2, 3)

# # Converting to set
# st = set([1, 2, 2, 3])  # st will be {1, 2, 3}

# # Converting to dictionary
# d = dict([(1, 'one'), (2, 'two')])  # d will be {1: 'one', 2: 'two'}
# Using format() method: You can use the format() method to convert one data type to another while formatting strings.
# python
# Copy code
# # Converting integer to string using format()
# s = "The value of x is {}".format(5)  # s will be "The value of x is 5"

# 3>Using eval() function: You can use the eval() function to evaluate a string containing Python expression and convert
# it into the appropriate data type.

# Example:
# # Converting string to integer using eval()
# x = eval("5")  # x will be 5

# %%
# Q4. How do you write and execute a Python script from the command line?
# Ans:-Writing and executing a Python script from the command line is straightforward. Follow these steps:

# 1:-Write Your Python Script:
# Create a new file with a .py extension. You can use any text editor to write your Python code.
# For example,
# let's create a file named my_script.py with the following content:

# # my_script.py
# print("Hello, World!")

# 2:-Save the File:
# Save the file with your Python code in a directory of your choice.

# 3:-Open Command Prompt or Terminal:
# Open the command prompt (Windows) or terminal (macOS/Linux).

# 4:-Navigate to the Directory:
# Use the cd command to navigate to the directory where your Python script is saved. 
# For example:
# cd path/to/your/directory

# 5:-Execute the Script:
# Once you are in the directory containing your Python script, 
# you can execute it by typing python followed by the name of your script file.
# For example:
# python my_script.py

# This command will execute the Python script my_script.py, 
# and you should see the output printed to the terminal:
# Hello, World!

# Alternatively, if you have multiple versions of Python installed on your system,
# you may need to specify the version explicitly. 
# For example:

# python3 my_script.py  # For Python 3.x

# %%
# Q5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain the sub-list [2, 3].
# Ans:-To obtain the sublist [2, 3] from the list my_list = [1, 2, 3, 4, 5], 
# you can use list slicing in Python.
# Here's the code:


# my_list = [1, 2, 3, 4, 5]

# # Slice the list to obtain the sublist [2, 3]
# sub_list = my_list[1:3]

# print(sub_list)  # Output: [2, 3]

# In Python, list slicing works as follows:

# my_list[start:end] returns a sublist starting from the index start (inclusive) up to, but not including,
# the index end (exclusive).
# If start is omitted, it defaults to the beginning of the list.
# If end is omitted, it defaults to the end of the list.
# So, my_list[1:3] slices my_list starting from index 1 (which corresponds to the second element, 2) up to, 
# but not including, index 3 (which corresponds to the fourth element, 4), resulting in the sublist [2, 3]

# %%
# Q6. What is a complex number in mathematics, and how is it represented in Python?
# Ans:-In mathematics, a complex number is a number that can be expressed in the form 
# 𝑎
# +
# 𝑏
# 𝑖
# a+bi, where 
# 𝑎
# a and 
# 𝑏
# b are real numbers, and 
# 𝑖
# i is the imaginary unit, which satisfies the equation 
# 𝑖
# 2
# =
# −
# 1
# i 
# 2
#  =−1. The real part of the complex number is 
# 𝑎
# a, and the imaginary part is 
# 𝑏
# 𝑖
# bi. Complex numbers extend the concept of the one-dimensional real numbers to the two-dimensional 
# complex plane by introducing the imaginary unit.

# In Python, complex numbers are represented using the complex data type.
# They are written in the form a + bj, where a is the real part, b is the imaginary part,
# and j represents the imaginary unit (in Python, j is used instead of i). 
# Here's an example of how complex numbers are represented in Python:


# # Define a complex number
# z = 3 + 4j

# # Print the complex number
# print(z)  # Output: (3+4j)

# # Access the real and imaginary parts
# real_part = z.real
# imaginary_part = z.imag

# print("Real part:", real_part)        # Output: 3.0
# print("Imaginary part:", imaginary_part)  # Output: 4.0

# %%
# Q7. What is the correct way to declare a variable named age and assign the value 25 to it?
# Ans:-The correct way to declare a variable named age and assign the value 25 to it in Python is as follows:


# age = 25

# In this statement:

# age is the variable name.
# = is the assignment operator, which assigns the value on the right-hand side to the variable on the left-hand side.
# 25 is the value assigned to the variable age.

# %%
# Q8. Declare a variable named price and assign the value 9.99 to it. What data type does this variable
# belong to?
# Ans:-To declare a variable named price and assign the value 9.99 to it in Python,
# you would do the following:


# price = 9.99
# In this statement:

# price is the variable name.
# = is the assignment operator.
# 9.99 is the value assigned to the variable price.

# %%
# Q9. Create a variable named name and assign your full name to it as a string. How would you print the
# value of this variable?
# Ans:-To create a variable named name and assign your full name to it as a string in Python, you would do the following:

# python
# Copy code
# name = "Your Full Name"
# Replace "Your Full Name" with your actual full name.

# To print the value of this variable, you can use the print() function:


# print(name)

# %%
# Q10. Given the string "Hello, World!", extract the substring "World".
# Ans:-To extract the substring "World" from the string "Hello, World!",
# you can use string slicing in Python. 
# Here's how you can do it:


# # Given string
# my_string = "Hello, World!"

# # Extracting the substring "World"
# substring = my_string[7:12]

# print(substring)  # Output: World

# In the above code:

# my_string[7:12] slices the string starting from index 7 (inclusive) up to index 
# 12 (exclusive), resulting in the substring "World".

# %%
# Q11. Create a variable named "is_student" and assign it a boolean value indicating whether you are
# currently a student or not.
# Ans:-To create a variable named is_student and assign it a boolean value indicating whether you 
# are currently a student or not, 
# you would do the following:


# is_student = True  # or False, depending on whether you are currently a student or not
# Assign True if you are currently a student, and False if you are not.

# For example, if you are currently a student, you would write:


# is_student = True
# If you are not currently a student, you would write:


# is_student = False
